# %%
# Created by: Prof. Valdecy Pereira, D.Sc.
# UFF - Universidade Federal Fluminense (Brazil)
# email:  valdecy.pereira@gmail.com
# Lesson: pyDecisions - AHP (Analytic Hierarchy Process)

# GitHub Repository: <https://github.com/Valdecy>

# %%
# !pip install pyDecision
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.1/225.1 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: importlib_metadata
#     Found existing installation: importlib-metadata 7.0.1
# ...

# %%
# Required Libraries
import numpy as np

# AHP
from pyDecision.algorithm import ahp_method

# %%
# AHP For Hazard Elements

# Parameters
weight_derivation = 'geometric' # 'mean'; 'geometric' or 'max_eigen'

# Dataset
dataset = np.array([
 [1.00, 2.00, 5.00, 6.00],#Temp
    [0.50, 1.00, 4.00, 5.00],#rainfall
    [0.20, 0.25, 1.00, 3.00],#NDBI
    [0.17, 0.20, 0.33, 1.00]#Distance to Waterbody
])

# %%
# Call AHP Function
weights, rc = ahp_method(dataset, wd = weight_derivation)

# %%
# Weigths
for i in range(0, weights.shape[0]):
  print('w(g'+str(i+1)+'): ', round(weights[i], 3))
# Out:
# w(g1):  0.505
# w(g2):  0.323
# w(g3):  0.113
# w(g4):  0.059

# %%
# Consistency Ratio
print('RC: ' + str(round(rc, 3)))
if (rc > 0.10):
  print('The solution is inconsistent, the pairwise comparisons must be reviewed')
else:
  print('The solution is consistent')
# Out:
# RC: 0.051
# The solution is consistent

# %%
# AHP For Vulnerability Elements

# Parameters
weight_derivation = 'geometric' # 'mean'; 'geometric' or 'max_eigen'

# Dataset
dataset = np.array([
 [1.00, 3.00, 2.00, 7.00, 3.00],#Pop_density
    [0.33, 1.00, 2.00, 4.00, 2.00],#Distance to hospital
    [0.50, 0.50, 1.00, 3.00, 2.00],#Elevation
    [0.14, 0.25, 0.33, 1.00, 0.25],#Female literacy
    [0.33, 0.50, 0.50, 4.00, 1.00]
])

# %%
# Call AHP Function
weights, rc = ahp_method(dataset, wd = weight_derivation)

# %%
# Weigths
for i in range(0, weights.shape[0]):
  print('w(g'+str(i+1)+'): ', round(weights[i], 3))
# Out:
# w(g1):  0.423
# w(g2):  0.224
# w(g3):  0.174
# w(g4):  0.05
# w(g5):  0.129

# %%
# Consistency Ratio
print('RC: ' + str(round(rc, 3)))
if (rc > 0.10):
  print('The solution is inconsistent, the pairwise comparisons must be reviewed')
else:
  print('The solution is consistent')
# Out:
# RC: 0.038
# The solution is consistent
